# %%
import matplotlib.pyplot as plt
plt.rc('font',family='Times New Roman') 
plt.rcParams['figure.figsize'] = (18, 2.5)

# %%
model_name = ['ProGAN','StyleGAN','BigGAN','CycleGAN','StarGAN','GauGAN','CRN','IMLE','SITD','SAN','DeepFake','StyleGAN2','WFIR']
Chance = [50,50,50,50,50,50,50,50,50,50,50,50,50]
NoAug = [100,96.6,72.1,76.1,100,59.3,97.8,94.1,98.9,91.1,96.4,99.8,97.5]
BlurOnly = [100,96.5,76.7,84.4,100,65.1,92.6,93.8,99.6,49.1,67.3,99.4,98.9]
JpegOnly = [100,96.2,74.7,86.2,95.9,90.3,99.4,99.6,85.0,69.3,88.5,94.6,95.3]
BlurJpeg = [100,97.7,78.1,91.9,98.2,92.4,96.7,98.1,99.2,56.2,65.9,98.5,99.7]
BlurJpeg1 = [100,93.6,72.1,81.7,99.2,73.1,87.7,81.5,98.8,54.5,67.7,97.4,97.5]


#准备X轴，宽带为0.3
bar_width = 0.15
x_14 = list(range(len(model_name)))
x_15 = [i + bar_width for i in x_14]
x_16 = [i + bar_width*2 for i in x_14]
x_17 = [i + bar_width*3 for i in x_14]
x_18 = [i + bar_width*4 for i in x_14]
x_19 = [i + bar_width*5 for i in x_14]
x_0 = [i + bar_width*2.5 for i in x_14]

#绘图
rect_0 = plt.bar(x_14,Chance,width=bar_width,label = 'Chance',color='lightsteelblue')
rect_1 = plt.bar(x_15,NoAug,width=bar_width,label = 'No Aug',color = 'orangered')
rect_2 = plt.bar(x_16,BlurOnly,width=bar_width,label = 'Blur only',color = 'orange')
rect_3 = plt.bar(x_17,JpegOnly,width=bar_width,label = 'JPEG only',color= 'gold')
rect_4 = plt.bar(x_18,BlurJpeg,width=bar_width,label = 'Blur+JPEG(0.5)',color = 'limegreen')
rect_5 = plt.bar(x_19,BlurJpeg1,width=bar_width,label = 'Blur+JPEG(0.1)',color='teal')


#X轴的刻度
plt.xticks(x_0,model_name)
plt.ylabel('AP',size=10)

#图例
plt.legend(bbox_to_anchor=(1, 1))
plt.savefig('aug_comp.jpg',dpi=200)
plt.show()

# %%
model_name = ['ProGAN','StyleGAN','BigGAN','CycleGAN','StarGAN','GauGAN','CRN','IMLE','SITD','SAN','DeepFake','StyleGAN2','WFIR']
Chance = [50,50,50,50,50,50,50,50,50,50,50,50,50]
class2 = [97.6,82.3,66.4,82.8,85.5,88.1,96.2,97.9,79.2,58.1,61.7,81.1,91.1]
class8 = [100,95.2,68.3,87.1,100,63.4,98.4,95.3,97.5,87.1,94.8,95.4,94.0]
class20 = [100,97.7,78.1,91.9,98.2,92.4,96.7,98.1,99.2,56.2,65.9,98.5,99.7]


#准备X轴，宽带为0.3
bar_width = 0.15
x_14 = list(range(len(model_name)))
x_15 = [i + bar_width for i in x_14]
x_16 = [i + bar_width*2 for i in x_14]
x_17 = [i + bar_width*3 for i in x_14]
x_18 = [i + bar_width*4 for i in x_14]
x_19 = [i + bar_width*5 for i in x_14]
x_0 = [i + bar_width*1.5 for i in x_14]

#绘图
rect_0 = plt.bar(x_14,Chance,width=bar_width,label = 'Chance',color='lightsteelblue')
rect_1 = plt.bar(x_15,class2,width=bar_width,label = '2 classes',color = 'orangered')
rect_2 = plt.bar(x_16,class8,width=bar_width,label = '8 classes',color = 'gold')
rect_3 = plt.bar(x_17,class20,width=bar_width,label = '20 classes',color= 'limegreen')



#X轴的刻度
plt.xticks(x_0,model_name)
plt.ylabel('AP',size=10)

#图例
plt.legend(bbox_to_anchor=(1, 1))
plt.savefig('div_comp.jpg',dpi=200)
plt.show()

# %%
import numpy as np
np.sum(class8)/13
# Out:
# 90.5
