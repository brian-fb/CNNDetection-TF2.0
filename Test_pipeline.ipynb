# %%
# !python test.py --checkpoint train_model/baseline-cp-8.ckpt --img_index Img_index/test/biggan_test.csv --root_dir ../CNN_synth_testset/biggan/
# Out:
# Model Loaded:train_model/baseline-cp-8.ckpt
#
# Testing on:../CNN_synth_testset/biggan/
# 2020-12-14 23:47:43.390803: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# 2020-12-14 23:47:44.745117: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library nvcuda.dll
# 2020-12-14 23:47:44.767042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce RTX 2070 SUPER computeCapability: 7.5
# coreClock: 1.77GHz coreCount: 40 deviceMemorySize: 8.00GiB deviceMemoryBandwidth: 417.29GiB/s
# 2020-12-14 23:47:44.767063: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# 2020-12-14 23:47:44.770030: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cublas64_10.dll
# ...

# %%
import tensorflow.keras as keras
import tensorflow as tf
from Data.DataPipe import TestDataGenerator
from Network.Det_RN50 import Det_RN50
import pandas as pd
import argparse

# %%
def Test(ckpt,img_idx,root,batch_size=64):
    model = Det_RN50()
    checkpoint_dir = ckpt
    model.load_weights(checkpoint_dir)
    
    optimizer = tf.optimizers.Adam(lr = 1e-4)
    loss=tf.keras.losses.BinaryCrossentropy(from_logits = True)
    model.compile(optimizer=optimizer,loss=loss,metrics=['accuracy'])
    
    img_idx = pd.read_csv(img_idx)
    
    Test_gen = TestDataGenerator(file_index = img_idx, root_dir = root, batch_size = batch_size)
    

    loss,acc = model.evaluate(Test_gen)
    return acc

# %%
Test(models[0], "Img_index/test/biggan_test.csv", "../CNN_synth_testset/biggan/", batch_size = 64)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.gamma
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.beta
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.kernel
# ...

# %%
models = ["train_model/baseline-cp-8.ckpt", "train_model/model2-cp-8.ckpt", "train_model/model3-cp-8.ckpt", 
          "train_model/model4-cp-8.ckpt", "train_model/model5-cp-8.ckpt"]
test_set = ["biggan", "crn", "cyclegan", "deepfake", "gaugan", "imle", "progan", "san", "seeingdark", 
            "stargan", "stylegan", "stylegan2"]

for model in models:
    for test_name in test_set:
        img_idx = "Img_index/test/" + test_name + "_test.csv"
        root = "../CNN_synth_testset/" + test_name + "/"
        print('\n\nModel Loaded:{}'.format(model))
        print('\nTesting on:{}\n'.format(test_name))
        Test(model, img_idx, root, batch_size = 64)
# Out:
# Model Loaded:train_model/baseline-cp-8.ckpt
#
# Testing on:biggan
#
# 62/62 [==============================] - 7s 108ms/step - loss: 2.4656 - accuracy: 0.5880
#
#
# Model Loaded:train_model/baseline-cp-8.ckpt
#
# Testing on:crn
#
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.gamma
# ...
